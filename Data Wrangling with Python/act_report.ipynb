# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# After saving the combination of the datasets into a new dataset, I read the newly combined file into the jupyter notebook.
#
# After this, I ran some codes to do some exploratory data analysis and see the dataset well. I ran the .info, .describe codes to see what was going on in there, and to draw some more insights.
#
# I found out the minimum and maximum values of some details, especially the number of retweets and favourites, which are represented in the retweet_count and favorite_count columns. The minimum number of retweets gotten for a tweet was 16, while the maximum number of retweets was 79515. The minimum number of likes gotten for a tweet was 81, while the maximum number of likes was 132810.
#
# Then using the .value_counts function, I checked for the dog breed that was most predicted in the first image prediction that was gotten using the neural network. I found out that the Golden Retriever breed was the most predicted, followed by the Labrador Retriever breed. After that was the Pembroke breed.
#
# I also checked for the means through which WeRateDogs did most of their tweets, and it was noticed that most of the tweets were from iPhone.
#
# I ran a simple visualization of an histogram through a key column on the dataset, the dog stages column. This is to see the distribution of the dog stages across the data set. I created a function for that, so the necessary variables could be slotted in for multiple visualizations. The distribution seemed to really have no regular pattern.
#
# The pupper dog stage had the highest number, followed by the doggo, then the doggo.pupper stage.

# %% [markdown]
# ### Visualization

# %%
from IPython import display
from base64 import b64decode
base64_data = "..."
display.Image(b64decode(base64_data))
